# %%
# from mrcnn.config import Config
# from mrcnn import model as modellib
# from mrcnn import visualize
# import mrcnn
# from mrcnn.utils import Dataset
# from mrcnn.model import MaskRCNN
# import numpy as np
# from numpy import zeros
# from numpy import asarray
# import colorsys
# import argparse
# import imutils
# import random
# import cv2
# import os
# import time
# from matplotlib import pyplot
# from matplotlib.patches import Rectangle
# from keras.models import load_model
# %matplotlib inline
# from os import listdir
# from xml.etree import ElementTree


import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon


# Import Mask RCNN
# sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

# %matplotlib inline
# Out:
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
# Run one of the code blocks

# Shapes toy dataset

# import shapes
# config = shapes.ShapesConfig()

# MS COCO Dataset
import coco
config = coco.CocoConfig()
COCO_DIR = "/home/cai/Desktop/simulation_synthetic_augmentation"  # TODO: enter value here

# %%
# from PIL import Image

# png_images = os.listdir(COCO_DIR + '/train2014/')
# for png_image in png_images:
    
#     try:
#         png = Image.open(COCO_DIR + '/train2014/' + str(png_image)[:-4] + '.png')
#         png.save(COCO_DIR + '/train2014/' + str(png_image)[:-4] + '.jpg')
#         os.remove(COCO_DIR + '/train2014/' + png_image)
        
#     except:
#         continue
        

# png_images = os.listdir(COCO_DIR + '/val2014/')
# for png_image in png_images:
    
#     try:
#         png = Image.open(COCO_DIR + '/val2014/' + str(png_image)[:-4] + '.png')
#         png.save(COCO_DIR + '/val2014/' + str(png_image)[:-4] + '.jpg')
#         os.remove(COCO_DIR + '/val2014/' + png_image)
        
#     except:
#         continue

# %%
# Load dataset
if config.NAME == 'shapes':
    dataset = shapes.ShapesDataset()
    dataset.load_shapes(500, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
elif config.NAME == "coco":
    dataset_train = coco.CocoDataset()
    dataset_train.load_coco(COCO_DIR, "train")
    dataset_val = coco.CocoDataset()
    dataset_val.load_coco(COCO_DIR, "val")

# Must call before using the dataset
dataset_train.prepare()
dataset_val.prepare()
print("Image Count: {}".format(len(dataset_train.image_ids)))
print("Class Count: {}".format(dataset_train.num_classes))
for i, info in enumerate(dataset_train.class_info):
    print("{:3}. {:50}".format(i, info['name']))
    
print("Image Count: {}".format(len(dataset_val.image_ids)))
print("Class Count: {}".format(dataset_val.num_classes))
for i, info in enumerate(dataset_val.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# loading annotations into memory...
# Done (t=17.86s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=9.31s)
# creating index...
# index created!
# Image Count: 14000
# Class Count: 2
#   0. BG
#   1. stone
# Image Count: 6000
# Class Count: 2
#   0. BG
#   1. stone

# %% [markdown]
# ## Display Samples
#
# Load and display images and masks.

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %% [markdown]
# ## Bounding Boxes
#
# Rather than using bounding box coordinates provided by the source datasets, we compute the bounding boxes from masks instead. This allows us to handle bounding boxes consistently regardless of the source dataset, and it also makes it easier to resize, rotate, or crop images because we simply generate the bounding boxes from the updates masks rather than computing bounding box transformation for each type of image transformation.

# %%
import mrcnn
import logging

# Load random image and mask.
image_id = random.choice(dataset_train.image_ids)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)
# Compute Bounding box
bbox = mrcnn.utils.extract_bboxes(mask)
# Display image and additional stats
print("image_id ", image_id, dataset_train.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset_train.class_names)
# Out:
# image_id  8256 http://cocodataset.org/#explore?id=8256
# image                    shape: (1275, 850, 3)        min:    0.00000  max:  255.00000  uint8
# mask                     shape: (1275, 850, 24)       min:    0.00000  max:    1.00000  bool
# class_ids                shape: (24,)                 min:    1.00000  max:    1.00000  int32
# bbox                     shape: (24, 4)               min:    0.00000  max: 1169.00000  int32

# %% [markdown]
# ## Resize Images
#
# To support multiple images per batch, images are resized to one size (1024x1024). Aspect ratio is preserved, though. If an image is not square, then zero padding is added at the top/bottom or right/left.

# %%
# Load random image and mask.
image_id = np.random.choice(dataset.image_ids, 1)[0]
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
original_shape = image.shape
# Resize
image, window, scale, padding, _ = utils.resize_image(
    image, 
    min_dim=config.IMAGE_MIN_DIM, 
    max_dim=config.IMAGE_MAX_DIM,
    mode=config.IMAGE_RESIZE_MODE)
mask = utils.resize_mask(mask, scale, padding)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id: ", image_id, dataset.image_reference(image_id))
print("Original shape: ", original_shape)
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %%
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, use_mini_mask=False)

log("image", image)
log("image_meta", image_meta)
log("class_ids", class_ids)
log("bbox", bbox)
log("mask", mask)

display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])

# %%
# Add augmentation and mask resizing.
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, augment=True, use_mini_mask=True)
log("mask", mask)
display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])

# %%
mask = utils.expand_mask(bbox, mask, image.shape)
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %%
ROOT_DIR = "/home/cai/Desktop/simulation_synthetic_augmentation/Mask_RCNN" 
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Which weights to start with?
init_with = "last"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)
# Out:
# Re-starting from epoch 30

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=100, 
            layers='all')
# Out:
# Starting at epoch 30. LR=0.001
#
# Checkpoint Path: /home/cai/Desktop/simulation_synthetic_augmentation/Mask_RCNN/logs/coco20201115T1741/mask_rcnn_coco_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/cai/anaconda3/envs/MRCNN/lib/python3.6/site-packages/keras/engine/training.py:2033: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 31/100
# 1000/1000 [==============================] - 1371s 1s/step - loss: 0.0644 - rpn_class_loss: 1.1548e-04 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0034 - mrcnn_mask_loss: 0.0480 - val_loss: 0.0744 - val_rpn_class_loss: 2.2284e-04 - val_rpn_bbox_loss: 0.0060 - val_mrcnn_class_loss: 0.0119 - val_mrcnn_bbox_loss: 0.0059 - val_mrcnn_mask_loss: 0.0504
# Epoch 32/100
# 1000/1000 [==============================] - 1114s 1s/step - loss: 0.0641 - rpn_class_loss: 1.0955e-04 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0096 - mrcnn_bbox_loss: 0.0033 - mrcnn_mask_loss: 0.0477 - val_loss: 0.0823 - val_rpn_class_loss: 1.9535e-04 - val_rpn_bbox_loss: 0.0058 - val_mrcnn_class_loss: 0.0140 - val_mrcnn_bbox_loss: 0.0087 - val_mrcnn_mask_loss: 0.0536
# Epoch 33/100
# 1000/1000 [==============================] - 1127s 1s/step - loss: 0.0637 - rpn_class_loss: 1.0154e-04 - rpn_bbox_loss: 0.0036 - mrcnn_class_loss: 0.0088 - mrcnn_bbox_loss: 0.0034 - mrcnn_mask_loss: 0.0479 - val_loss: 0.0740 - val_rpn_class_loss: 1.6650e-04 - val_rpn_bbox_loss: 0.0048 - val_mrcnn_class_loss: 0.0122 - val_mrcnn_bbox_loss: 0.0059 - val_mrcnn_mask_loss: 0.0510
# Epoch 34/100
# 1000/1000 [==============================] - 1120s 1s/step - loss: 0.0634 - rpn_class_loss: 1.0673e-04 - rpn_bbox_loss: 0.0035 - mrcnn_class_loss: 0.0086 - mrcnn_bbox_loss: 0.0033 - mrcnn_mask_loss: 0.0479 - val_loss: 0.0932 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.0173 - val_mrcnn_class_loss: 0.0127 - val_mrcnn_bbox_loss: 0.0055 - val_mrcnn_mask_loss: 0.0481
# Epoch 35/100
# 1000/1000 [==============================] - 1119s 1s/step - loss: 0.0619 - rpn_class_loss: 9.2296e-05 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0083 - mrcnn_bbox_loss: 0.0030 - mrcnn_mask_loss: 0.0474 - val_loss: 0.0807 - val_rpn_class_loss: 0.0010 - val_rpn_bbox_loss: 0.0062 - val_mrcnn_class_loss: 0.0152 - val_mrcnn_bbox_loss: 0.0062 - val_mrcnn_mask_loss: 0.0520
# Epoch 36/100
# 1000/1000 [==============================] - 1118s 1s/step - loss: 0.0634 - rpn_class_loss: 1.0328e-04 - rpn_bbox_loss: 0.0031 - mrcnn_class_loss: 0.0098 - mrcnn_bbox_loss: 0.0032 - mrcnn_mask_loss: 0.0473 - val_loss: 0.0688 - val_rpn_class_loss: 2.7324e-04 - val_rpn_bbox_loss: 0.0045 - val_mrcnn_class_loss: 0.0116 - val_mrcnn_bbox_loss: 0.0042 - val_mrcnn_mask_loss: 0.0482
# Epoch 37/100
# 1000/1000 [==============================] - 1108s 1s/step - loss: 0.0638 - rpn_class_loss: 1.2591e-04 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0104 - mrcnn_bbox_loss: 0.0032 - mrcnn_mask_loss: 0.0468 - val_loss: 0.0756 - val_rpn_class_loss: 0.0010 - val_rpn_bbox_loss: 0.0060 - val_mrcnn_class_loss: 0.0137 - val_mrcnn_bbox_loss: 0.0062 - val_mrcnn_mask_loss: 0.0487
# Epoch 38/100
# 1000/1000 [==============================] - 1103s 1s/step - loss: 0.0629 - rpn_class_loss: 1.0957e-04 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0102 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0463 - val_loss: 0.0718 - val_rpn_class_loss: 2.0361e-04 - val_rpn_bbox_loss: 0.0044 - val_mrcnn_class_loss: 0.0133 - val_mrcnn_bbox_loss: 0.0045 - val_mrcnn_mask_loss: 0.0492
# Epoch 39/100
# 1000/1000 [==============================] - 1126s 1s/step - loss: 0.0614 - rpn_class_loss: 9.8006e-05 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0028 - mrcnn_mask_loss: 0.0459 - val_loss: 0.0814 - val_rpn_class_loss: 8.2621e-04 - val_rpn_bbox_loss: 0.0061 - val_mrcnn_class_loss: 0.0172 - val_mrcnn_bbox_loss: 0.0071 - val_mrcnn_mask_loss: 0.0501
# Epoch 40/100
# 1000/1000 [==============================] - 1130s 1s/step - loss: 0.0609 - rpn_class_loss: 9.5148e-05 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0028 - mrcnn_mask_loss: 0.0456 - val_loss: 0.0767 - val_rpn_class_loss: 2.9740e-04 - val_rpn_bbox_loss: 0.0049 - val_mrcnn_class_loss: 0.0147 - val_mrcnn_bbox_loss: 0.0074 - val_mrcnn_mask_loss: 0.0495
# Epoch 41/100
# 1000/1000 [==============================] - 1120s 1s/step - loss: 0.0616 - rpn_class_loss: 1.0338e-04 - rpn_bbox_loss: 0.0035 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0027 - mrcnn_mask_loss: 0.0456 - val_loss: 0.0819 - val_rpn_class_loss: 7.9203e-04 - val_rpn_bbox_loss: 0.0066 - val_mrcnn_class_loss: 0.0176 - val_mrcnn_bbox_loss: 0.0079 - val_mrcnn_mask_loss: 0.0490
# Epoch 42/100
# 1000/1000 [==============================] - 1119s 1s/step - loss: 0.0602 - rpn_class_loss: 8.0825e-05 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0093 - mrcnn_bbox_loss: 0.0027 - mrcnn_mask_loss: 0.0453 - val_loss: 0.0729 - val_rpn_class_loss: 2.2336e-04 - val_rpn_bbox_loss: 0.0042 - val_mrcnn_class_loss: 0.0151 - val_mrcnn_bbox_loss: 0.0056 - val_mrcnn_mask_loss: 0.0478
# Epoch 43/100
# 1000/1000 [==============================] - 1124s 1s/step - loss: 0.0606 - rpn_class_loss: 7.6564e-05 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0101 - mrcnn_bbox_loss: 0.0026 - mrcnn_mask_loss: 0.0449 - val_loss: 0.0707 - val_rpn_class_loss: 8.3417e-05 - val_rpn_bbox_loss: 0.0043 - val_mrcnn_class_loss: 0.0136 - val_mrcnn_bbox_loss: 0.0050 - val_mrcnn_mask_loss: 0.0477
# Epoch 44/100
# 1000/1000 [==============================] - 1099s 1s/step - loss: 0.0600 - rpn_class_loss: 7.7381e-05 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0099 - mrcnn_bbox_loss: 0.0025 - mrcnn_mask_loss: 0.0448 - val_loss: 0.0812 - val_rpn_class_loss: 9.6776e-04 - val_rpn_bbox_loss: 0.0070 - val_mrcnn_class_loss: 0.0191 - val_mrcnn_bbox_loss: 0.0061 - val_mrcnn_mask_loss: 0.0480
# Epoch 45/100
# 1000/1000 [==============================] - 1114s 1s/step - loss: 0.0600 - rpn_class_loss: 1.0204e-04 - rpn_bbox_loss: 0.0028 - mrcnn_class_loss: 0.0096 - mrcnn_bbox_loss: 0.0026 - mrcnn_mask_loss: 0.0448 - val_loss: 0.0742 - val_rpn_class_loss: 2.5953e-04 - val_rpn_bbox_loss: 0.0049 - val_mrcnn_class_loss: 0.0152 - val_mrcnn_bbox_loss: 0.0062 - val_mrcnn_mask_loss: 0.0476
# Epoch 46/100
# 1000/1000 [==============================] - 1125s 1s/step - loss: 0.0589 - rpn_class_loss: 8.1665e-05 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0087 - mrcnn_bbox_loss: 0.0025 - mrcnn_mask_loss: 0.0449 - val_loss: 0.0728 - val_rpn_class_loss: 0.0011 - val_rpn_bbox_loss: 0.0064 - val_mrcnn_class_loss: 0.0139 - val_mrcnn_bbox_loss: 0.0054 - val_mrcnn_mask_loss: 0.0459
# Epoch 47/100
# 1000/1000 [==============================] - 1128s 1s/step - loss: 0.0587 - rpn_class_loss: 8.2072e-05 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0090 - mrcnn_bbox_loss: 0.0025 - mrcnn_mask_loss: 0.0445 - val_loss: 0.0799 - val_rpn_class_loss: 2.6510e-04 - val_rpn_bbox_loss: 0.0049 - val_mrcnn_class_loss: 0.0183 - val_mrcnn_bbox_loss: 0.0065 - val_mrcnn_mask_loss: 0.0500
# Epoch 48/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0590 - rpn_class_loss: 8.7599e-05 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0086 - mrcnn_bbox_loss: 0.0026 - mrcnn_mask_loss: 0.0446 - val_loss: 0.0675 - val_rpn_class_loss: 1.3568e-04 - val_rpn_bbox_loss: 0.0047 - val_mrcnn_class_loss: 0.0115 - val_mrcnn_bbox_loss: 0.0051 - val_mrcnn_mask_loss: 0.0461
# Epoch 49/100
# 1000/1000 [==============================] - 1124s 1s/step - loss: 0.0573 - rpn_class_loss: 8.8841e-05 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0024 - mrcnn_mask_loss: 0.0442 - val_loss: 0.0750 - val_rpn_class_loss: 0.0023 - val_rpn_bbox_loss: 0.0063 - val_mrcnn_class_loss: 0.0129 - val_mrcnn_bbox_loss: 0.0059 - val_mrcnn_mask_loss: 0.0476
# Epoch 50/100
# 1000/1000 [==============================] - 1110s 1s/step - loss: 0.0576 - rpn_class_loss: 7.9510e-05 - rpn_bbox_loss: 0.0029 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0024 - mrcnn_mask_loss: 0.0442 - val_loss: 0.0708 - val_rpn_class_loss: 1.7876e-04 - val_rpn_bbox_loss: 0.0041 - val_mrcnn_class_loss: 0.0129 - val_mrcnn_bbox_loss: 0.0057 - val_mrcnn_mask_loss: 0.0479
# Epoch 51/100
# 1000/1000 [==============================] - 1110s 1s/step - loss: 0.0562 - rpn_class_loss: 6.6615e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0023 - mrcnn_mask_loss: 0.0443 - val_loss: 0.0688 - val_rpn_class_loss: 2.3306e-04 - val_rpn_bbox_loss: 0.0045 - val_mrcnn_class_loss: 0.0114 - val_mrcnn_bbox_loss: 0.0052 - val_mrcnn_mask_loss: 0.0475
# Epoch 52/100
# 1000/1000 [==============================] - 1124s 1s/step - loss: 0.0568 - rpn_class_loss: 6.8018e-05 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0023 - mrcnn_mask_loss: 0.0440 - val_loss: 0.0696 - val_rpn_class_loss: 6.8612e-04 - val_rpn_bbox_loss: 0.0048 - val_mrcnn_class_loss: 0.0115 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0480
# Epoch 53/100
# 1000/1000 [==============================] - 1099s 1s/step - loss: 0.0564 - rpn_class_loss: 6.8414e-05 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0078 - mrcnn_bbox_loss: 0.0022 - mrcnn_mask_loss: 0.0437 - val_loss: 0.0733 - val_rpn_class_loss: 7.9963e-04 - val_rpn_bbox_loss: 0.0047 - val_mrcnn_class_loss: 0.0145 - val_mrcnn_bbox_loss: 0.0052 - val_mrcnn_mask_loss: 0.0482
# Epoch 54/100
# 1000/1000 [==============================] - 1120s 1s/step - loss: 0.0575 - rpn_class_loss: 7.9031e-05 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0084 - mrcnn_bbox_loss: 0.0024 - mrcnn_mask_loss: 0.0440 - val_loss: 0.0780 - val_rpn_class_loss: 5.2791e-04 - val_rpn_bbox_loss: 0.0052 - val_mrcnn_class_loss: 0.0175 - val_mrcnn_bbox_loss: 0.0058 - val_mrcnn_mask_loss: 0.0490
# Epoch 55/100
# 1000/1000 [==============================] - 1119s 1s/step - loss: 0.0569 - rpn_class_loss: 6.9162e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0085 - mrcnn_bbox_loss: 0.0022 - mrcnn_mask_loss: 0.0435 - val_loss: 0.0730 - val_rpn_class_loss: 2.3564e-04 - val_rpn_bbox_loss: 0.0050 - val_mrcnn_class_loss: 0.0156 - val_mrcnn_bbox_loss: 0.0055 - val_mrcnn_mask_loss: 0.0467
# Epoch 56/100
# 1000/1000 [==============================] - 1117s 1s/step - loss: 0.0568 - rpn_class_loss: 6.0759e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0084 - mrcnn_bbox_loss: 0.0023 - mrcnn_mask_loss: 0.0437 - val_loss: 0.0699 - val_rpn_class_loss: 2.3858e-04 - val_rpn_bbox_loss: 0.0048 - val_mrcnn_class_loss: 0.0138 - val_mrcnn_bbox_loss: 0.0047 - val_mrcnn_mask_loss: 0.0463
# Epoch 57/100
# 1000/1000 [==============================] - 1101s 1s/step - loss: 0.0562 - rpn_class_loss: 8.2149e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0078 - mrcnn_bbox_loss: 0.0022 - mrcnn_mask_loss: 0.0437 - val_loss: 0.0804 - val_rpn_class_loss: 0.0018 - val_rpn_bbox_loss: 0.0075 - val_mrcnn_class_loss: 0.0171 - val_mrcnn_bbox_loss: 0.0056 - val_mrcnn_mask_loss: 0.0484
# Epoch 58/100
# 1000/1000 [==============================] - 1117s 1s/step - loss: 0.0552 - rpn_class_loss: 7.0269e-05 - rpn_bbox_loss: 0.0023 - mrcnn_class_loss: 0.0076 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0431 - val_loss: 0.0687 - val_rpn_class_loss: 2.7638e-04 - val_rpn_bbox_loss: 0.0044 - val_mrcnn_class_loss: 0.0132 - val_mrcnn_bbox_loss: 0.0043 - val_mrcnn_mask_loss: 0.0466
# Epoch 59/100
# 1000/1000 [==============================] - 1108s 1s/step - loss: 0.0562 - rpn_class_loss: 7.0799e-05 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0081 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0432 - val_loss: 0.0748 - val_rpn_class_loss: 5.1368e-04 - val_rpn_bbox_loss: 0.0054 - val_mrcnn_class_loss: 0.0153 - val_mrcnn_bbox_loss: 0.0058 - val_mrcnn_mask_loss: 0.0478
# Epoch 60/100
# 1000/1000 [==============================] - 1079s 1s/step - loss: 0.0559 - rpn_class_loss: 6.1438e-05 - rpn_bbox_loss: 0.0023 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0425 - val_loss: 0.0642 - val_rpn_class_loss: 3.5603e-04 - val_rpn_bbox_loss: 0.0042 - val_mrcnn_class_loss: 0.0107 - val_mrcnn_bbox_loss: 0.0040 - val_mrcnn_mask_loss: 0.0449
# Epoch 61/100
# 1000/1000 [==============================] - 1107s 1s/step - loss: 0.0552 - rpn_class_loss: 7.1132e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0081 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0426 - val_loss: 0.0747 - val_rpn_class_loss: 5.7186e-04 - val_rpn_bbox_loss: 0.0051 - val_mrcnn_class_loss: 0.0151 - val_mrcnn_bbox_loss: 0.0062 - val_mrcnn_mask_loss: 0.0477
# Epoch 62/100
# 1000/1000 [==============================] - 1127s 1s/step - loss: 0.0558 - rpn_class_loss: 6.8504e-05 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0083 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0426 - val_loss: 0.0691 - val_rpn_class_loss: 4.7163e-04 - val_rpn_bbox_loss: 0.0045 - val_mrcnn_class_loss: 0.0143 - val_mrcnn_bbox_loss: 0.0048 - val_mrcnn_mask_loss: 0.0449
# Epoch 63/100
# 1000/1000 [==============================] - 1124s 1s/step - loss: 0.0550 - rpn_class_loss: 4.9826e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0020 - mrcnn_mask_loss: 0.0426 - val_loss: 0.0632 - val_rpn_class_loss: 7.2775e-05 - val_rpn_bbox_loss: 0.0038 - val_mrcnn_class_loss: 0.0093 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0453
# Epoch 64/100
# 1000/1000 [==============================] - 1114s 1s/step - loss: 0.0549 - rpn_class_loss: 6.8559e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0428 - val_loss: 0.0667 - val_rpn_class_loss: 2.4023e-04 - val_rpn_bbox_loss: 0.0041 - val_mrcnn_class_loss: 0.0115 - val_mrcnn_bbox_loss: 0.0053 - val_mrcnn_mask_loss: 0.0455
# Epoch 65/100
# 1000/1000 [==============================] - 1113s 1s/step - loss: 0.0553 - rpn_class_loss: 7.0840e-05 - rpn_bbox_loss: 0.0026 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0021 - mrcnn_mask_loss: 0.0426 - val_loss: 0.0645 - val_rpn_class_loss: 1.2299e-04 - val_rpn_bbox_loss: 0.0038 - val_mrcnn_class_loss: 0.0111 - val_mrcnn_bbox_loss: 0.0042 - val_mrcnn_mask_loss: 0.0452
# Epoch 66/100
# 1000/1000 [==============================] - 1100s 1s/step - loss: 0.0550 - rpn_class_loss: 6.4128e-05 - rpn_bbox_loss: 0.0022 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0020 - mrcnn_mask_loss: 0.0425 - val_loss: 0.0651 - val_rpn_class_loss: 9.6072e-05 - val_rpn_bbox_loss: 0.0036 - val_mrcnn_class_loss: 0.0131 - val_mrcnn_bbox_loss: 0.0037 - val_mrcnn_mask_loss: 0.0447
# Epoch 67/100
# 1000/1000 [==============================] - 1109s 1s/step - loss: 0.0546 - rpn_class_loss: 6.9008e-05 - rpn_bbox_loss: 0.0022 - mrcnn_class_loss: 0.0081 - mrcnn_bbox_loss: 0.0020 - mrcnn_mask_loss: 0.0422 - val_loss: 0.0651 - val_rpn_class_loss: 1.7080e-04 - val_rpn_bbox_loss: 0.0039 - val_mrcnn_class_loss: 0.0128 - val_mrcnn_bbox_loss: 0.0036 - val_mrcnn_mask_loss: 0.0446
# Epoch 68/100
# 1000/1000 [==============================] - 1110s 1s/step - loss: 0.0543 - rpn_class_loss: 4.7908e-05 - rpn_bbox_loss: 0.0021 - mrcnn_class_loss: 0.0077 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0425 - val_loss: 0.0622 - val_rpn_class_loss: 7.9148e-05 - val_rpn_bbox_loss: 0.0033 - val_mrcnn_class_loss: 0.0103 - val_mrcnn_bbox_loss: 0.0038 - val_mrcnn_mask_loss: 0.0447
# Epoch 69/100
# 1000/1000 [==============================] - 1121s 1s/step - loss: 0.0544 - rpn_class_loss: 6.1271e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0020 - mrcnn_mask_loss: 0.0425 - val_loss: 0.0721 - val_rpn_class_loss: 6.6375e-04 - val_rpn_bbox_loss: 0.0042 - val_mrcnn_class_loss: 0.0147 - val_mrcnn_bbox_loss: 0.0058 - val_mrcnn_mask_loss: 0.0468
# Epoch 70/100
# 1000/1000 [==============================] - 1106s 1s/step - loss: 0.0538 - rpn_class_loss: 6.0089e-05 - rpn_bbox_loss: 0.0022 - mrcnn_class_loss: 0.0073 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0424 - val_loss: 0.0666 - val_rpn_class_loss: 7.8700e-04 - val_rpn_bbox_loss: 0.0044 - val_mrcnn_class_loss: 0.0123 - val_mrcnn_bbox_loss: 0.0043 - val_mrcnn_mask_loss: 0.0448
# Epoch 71/100
# 1000/1000 [==============================] - 1124s 1s/step - loss: 0.0540 - rpn_class_loss: 7.7309e-05 - rpn_bbox_loss: 0.0025 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0421 - val_loss: 0.0652 - val_rpn_class_loss: 8.9990e-05 - val_rpn_bbox_loss: 0.0035 - val_mrcnn_class_loss: 0.0098 - val_mrcnn_bbox_loss: 0.0048 - val_mrcnn_mask_loss: 0.0471
# Epoch 72/100
# 1000/1000 [==============================] - 1114s 1s/step - loss: 0.0544 - rpn_class_loss: 7.0513e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0418 - val_loss: 0.0698 - val_rpn_class_loss: 0.0018 - val_rpn_bbox_loss: 0.0068 - val_mrcnn_class_loss: 0.0129 - val_mrcnn_bbox_loss: 0.0040 - val_mrcnn_mask_loss: 0.0444
# Epoch 73/100
# 1000/1000 [==============================] - 1117s 1s/step - loss: 0.0530 - rpn_class_loss: 5.9608e-05 - rpn_bbox_loss: 0.0021 - mrcnn_class_loss: 0.0072 - mrcnn_bbox_loss: 0.0018 - mrcnn_mask_loss: 0.0419 - val_loss: 0.0663 - val_rpn_class_loss: 5.5632e-04 - val_rpn_bbox_loss: 0.0048 - val_mrcnn_class_loss: 0.0116 - val_mrcnn_bbox_loss: 0.0038 - val_mrcnn_mask_loss: 0.0456
# Epoch 74/100
# 1000/1000 [==============================] - 1111s 1s/step - loss: 0.0537 - rpn_class_loss: 5.7773e-05 - rpn_bbox_loss: 0.0024 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0019 - mrcnn_mask_loss: 0.0420 - val_loss: 0.0640 - val_rpn_class_loss: 5.5876e-05 - val_rpn_bbox_loss: 0.0034 - val_mrcnn_class_loss: 0.0111 - val_mrcnn_bbox_loss: 0.0042 - val_mrcnn_mask_loss: 0.0451
# Epoch 75/100
# 1000/1000 [==============================] - 1110s 1s/step - loss: 0.0525 - rpn_class_loss: 6.3851e-05 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0018 - mrcnn_mask_loss: 0.0418 - val_loss: 0.0710 - val_rpn_class_loss: 3.9692e-04 - val_rpn_bbox_loss: 0.0055 - val_mrcnn_class_loss: 0.0124 - val_mrcnn_bbox_loss: 0.0057 - val_mrcnn_mask_loss: 0.0469
# Epoch 76/100
# 1000/1000 [==============================] - 1106s 1s/step - loss: 0.0526 - rpn_class_loss: 5.0822e-05 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0071 - mrcnn_bbox_loss: 0.0018 - mrcnn_mask_loss: 0.0417 - val_loss: 0.0690 - val_rpn_class_loss: 8.7690e-04 - val_rpn_bbox_loss: 0.0056 - val_mrcnn_class_loss: 0.0128 - val_mrcnn_bbox_loss: 0.0051 - val_mrcnn_mask_loss: 0.0446
# Epoch 77/100
# 1000/1000 [==============================] - 1126s 1s/step - loss: 0.0530 - rpn_class_loss: 7.0499e-05 - rpn_bbox_loss: 0.0021 - mrcnn_class_loss: 0.0077 - mrcnn_bbox_loss: 0.0018 - mrcnn_mask_loss: 0.0412 - val_loss: 0.0915 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.0193 - val_mrcnn_class_loss: 0.0128 - val_mrcnn_bbox_loss: 0.0034 - val_mrcnn_mask_loss: 0.0439
# Epoch 78/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0536 - rpn_class_loss: 6.4215e-05 - rpn_bbox_loss: 0.0021 - mrcnn_class_loss: 0.0085 - mrcnn_bbox_loss: 0.0018 - mrcnn_mask_loss: 0.0412 - val_loss: 0.0684 - val_rpn_class_loss: 1.1174e-04 - val_rpn_bbox_loss: 0.0038 - val_mrcnn_class_loss: 0.0132 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0467
# Epoch 79/100
# 1000/1000 [==============================] - 1121s 1s/step - loss: 0.0517 - rpn_class_loss: 4.1987e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0411 - val_loss: 0.0835 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.0095 - val_mrcnn_class_loss: 0.0150 - val_mrcnn_bbox_loss: 0.0064 - val_mrcnn_mask_loss: 0.0477
# Epoch 80/100
# 1000/1000 [==============================] - 1120s 1s/step - loss: 0.0524 - rpn_class_loss: 6.4691e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0412 - val_loss: 0.0680 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.0058 - val_mrcnn_class_loss: 0.0114 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0442
# Epoch 81/100
# 1000/1000 [==============================] - 1107s 1s/step - loss: 0.0523 - rpn_class_loss: 6.6583e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0412 - val_loss: 0.0694 - val_rpn_class_loss: 2.9410e-04 - val_rpn_bbox_loss: 0.0043 - val_mrcnn_class_loss: 0.0131 - val_mrcnn_bbox_loss: 0.0054 - val_mrcnn_mask_loss: 0.0463
# Epoch 82/100
# 1000/1000 [==============================] - 1132s 1s/step - loss: 0.0511 - rpn_class_loss: 5.2777e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0409 - val_loss: 0.0731 - val_rpn_class_loss: 6.4535e-04 - val_rpn_bbox_loss: 0.0041 - val_mrcnn_class_loss: 0.0170 - val_mrcnn_bbox_loss: 0.0051 - val_mrcnn_mask_loss: 0.0462
# Epoch 83/100
# 1000/1000 [==============================] - 1117s 1s/step - loss: 0.0524 - rpn_class_loss: 4.4681e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0413 - val_loss: 0.0695 - val_rpn_class_loss: 3.8977e-05 - val_rpn_bbox_loss: 0.0037 - val_mrcnn_class_loss: 0.0154 - val_mrcnn_bbox_loss: 0.0052 - val_mrcnn_mask_loss: 0.0451
# Epoch 84/100
# 1000/1000 [==============================] - 1112s 1s/step - loss: 0.0517 - rpn_class_loss: 4.6076e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0412 - val_loss: 0.0714 - val_rpn_class_loss: 0.0024 - val_rpn_bbox_loss: 0.0063 - val_mrcnn_class_loss: 0.0119 - val_mrcnn_bbox_loss: 0.0050 - val_mrcnn_mask_loss: 0.0459
# Epoch 85/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0528 - rpn_class_loss: 4.4769e-05 - rpn_bbox_loss: 0.0022 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0410 - val_loss: 0.0686 - val_rpn_class_loss: 4.9897e-04 - val_rpn_bbox_loss: 0.0041 - val_mrcnn_class_loss: 0.0141 - val_mrcnn_bbox_loss: 0.0050 - val_mrcnn_mask_loss: 0.0449
# Epoch 86/100
# 1000/1000 [==============================] - 1099s 1s/step - loss: 0.0522 - rpn_class_loss: 6.0561e-05 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0076 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0409 - val_loss: 0.0708 - val_rpn_class_loss: 0.0027 - val_rpn_bbox_loss: 0.0057 - val_mrcnn_class_loss: 0.0125 - val_mrcnn_bbox_loss: 0.0040 - val_mrcnn_mask_loss: 0.0459
# Epoch 87/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0519 - rpn_class_loss: 4.4464e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0405 - val_loss: 0.0816 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.0064 - val_mrcnn_class_loss: 0.0191 - val_mrcnn_bbox_loss: 0.0058 - val_mrcnn_mask_loss: 0.0469
# Epoch 88/100
# 1000/1000 [==============================] - 1117s 1s/step - loss: 0.0518 - rpn_class_loss: 4.8736e-05 - rpn_bbox_loss: 0.0023 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0404 - val_loss: 0.0596 - val_rpn_class_loss: 3.2988e-05 - val_rpn_bbox_loss: 0.0030 - val_mrcnn_class_loss: 0.0094 - val_mrcnn_bbox_loss: 0.0035 - val_mrcnn_mask_loss: 0.0436
# Epoch 89/100
# 1000/1000 [==============================] - 1129s 1s/step - loss: 0.0513 - rpn_class_loss: 4.2268e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0404 - val_loss: 0.0733 - val_rpn_class_loss: 0.0013 - val_rpn_bbox_loss: 0.0045 - val_mrcnn_class_loss: 0.0168 - val_mrcnn_bbox_loss: 0.0053 - val_mrcnn_mask_loss: 0.0455
# Epoch 90/100
# 1000/1000 [==============================] - 1108s 1s/step - loss: 0.0514 - rpn_class_loss: 4.9050e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0076 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0404 - val_loss: 0.0709 - val_rpn_class_loss: 6.0361e-04 - val_rpn_bbox_loss: 0.0045 - val_mrcnn_class_loss: 0.0132 - val_mrcnn_bbox_loss: 0.0061 - val_mrcnn_mask_loss: 0.0466
# Epoch 91/100
# 1000/1000 [==============================] - 1121s 1s/step - loss: 0.0514 - rpn_class_loss: 3.9057e-05 - rpn_bbox_loss: 0.0019 - mrcnn_class_loss: 0.0073 - mrcnn_bbox_loss: 0.0017 - mrcnn_mask_loss: 0.0405 - val_loss: 0.0697 - val_rpn_class_loss: 5.5466e-04 - val_rpn_bbox_loss: 0.0048 - val_mrcnn_class_loss: 0.0142 - val_mrcnn_bbox_loss: 0.0051 - val_mrcnn_mask_loss: 0.0451
# Epoch 92/100
# 1000/1000 [==============================] - 1104s 1s/step - loss: 0.0521 - rpn_class_loss: 5.1342e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0404 - val_loss: 0.0697 - val_rpn_class_loss: 0.0014 - val_rpn_bbox_loss: 0.0055 - val_mrcnn_class_loss: 0.0135 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0448
# Epoch 93/100
# 1000/1000 [==============================] - 1127s 1s/step - loss: 0.0516 - rpn_class_loss: 5.5428e-05 - rpn_bbox_loss: 0.0022 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0402 - val_loss: 0.0668 - val_rpn_class_loss: 6.6952e-04 - val_rpn_bbox_loss: 0.0042 - val_mrcnn_class_loss: 0.0127 - val_mrcnn_bbox_loss: 0.0046 - val_mrcnn_mask_loss: 0.0447
# Epoch 94/100
# 1000/1000 [==============================] - 1131s 1s/step - loss: 0.0508 - rpn_class_loss: 6.3801e-05 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0016 - mrcnn_mask_loss: 0.0396 - val_loss: 0.0638 - val_rpn_class_loss: 1.0508e-04 - val_rpn_bbox_loss: 0.0041 - val_mrcnn_class_loss: 0.0113 - val_mrcnn_bbox_loss: 0.0043 - val_mrcnn_mask_loss: 0.0440
# Epoch 95/100
# 1000/1000 [==============================] - 1119s 1s/step - loss: 0.0494 - rpn_class_loss: 5.2268e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0057 - mrcnn_bbox_loss: 0.0015 - mrcnn_mask_loss: 0.0403 - val_loss: 0.0688 - val_rpn_class_loss: 0.0023 - val_rpn_bbox_loss: 0.0038 - val_mrcnn_class_loss: 0.0133 - val_mrcnn_bbox_loss: 0.0047 - val_mrcnn_mask_loss: 0.0448
# Epoch 96/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0489 - rpn_class_loss: 5.2884e-05 - rpn_bbox_loss: 0.0017 - mrcnn_class_loss: 0.0060 - mrcnn_bbox_loss: 0.0014 - mrcnn_mask_loss: 0.0399 - val_loss: 0.0985 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.0211 - val_mrcnn_class_loss: 0.0133 - val_mrcnn_bbox_loss: 0.0050 - val_mrcnn_mask_loss: 0.0455
# Epoch 97/100
# 1000/1000 [==============================] - 1115s 1s/step - loss: 0.0497 - rpn_class_loss: 4.4797e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0066 - mrcnn_bbox_loss: 0.0015 - mrcnn_mask_loss: 0.0398 - val_loss: 0.0660 - val_rpn_class_loss: 0.0015 - val_rpn_bbox_loss: 0.0053 - val_mrcnn_class_loss: 0.0121 - val_mrcnn_bbox_loss: 0.0042 - val_mrcnn_mask_loss: 0.0429
# Epoch 98/100
# 1000/1000 [==============================] - 1127s 1s/step - loss: 0.0500 - rpn_class_loss: 4.1609e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0015 - mrcnn_mask_loss: 0.0398 - val_loss: 0.0630 - val_rpn_class_loss: 0.0021 - val_rpn_bbox_loss: 0.0069 - val_mrcnn_class_loss: 0.0089 - val_mrcnn_bbox_loss: 0.0034 - val_mrcnn_mask_loss: 0.0417
# Epoch 99/100
# 1000/1000 [==============================] - 1103s 1s/step - loss: 0.0498 - rpn_class_loss: 6.1418e-05 - rpn_bbox_loss: 0.0020 - mrcnn_class_loss: 0.0066 - mrcnn_bbox_loss: 0.0015 - mrcnn_mask_loss: 0.0397 - val_loss: 0.0641 - val_rpn_class_loss: 5.7830e-04 - val_rpn_bbox_loss: 0.0058 - val_mrcnn_class_loss: 0.0106 - val_mrcnn_bbox_loss: 0.0037 - val_mrcnn_mask_loss: 0.0435
# Epoch 100/100
# 1000/1000 [==============================] - 1098s 1s/step - loss: 0.0493 - rpn_class_loss: 4.1401e-05 - rpn_bbox_loss: 0.0018 - mrcnn_class_loss: 0.0065 - mrcnn_bbox_loss: 0.0015 - mrcnn_mask_loss: 0.0394 - val_loss: 0.0646 - val_rpn_class_loss: 1.5141e-04 - val_rpn_bbox_loss: 0.0035 - val_mrcnn_class_loss: 0.0106 - val_mrcnn_bbox_loss: 0.0048 - val_mrcnn_mask_loss: 0.0455

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(coco.CocoConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /home/cai/Desktop/simulation_synthetic_augmentation/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Loading weights from  /home/cai/Desktop/simulation_synthetic_augmentation/Mask_RCNN/logs/coco20201115T1741/mask_rcnn_coco_0100.h5
# Re-starting from epoch 100

# %%
inference_config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (14,)                 min:    0.00000  max: 2518.00000  float64
# gt_class_id              shape: (24,)                 min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (24, 4)               min:    0.00000  max:  954.00000  int32
# gt_mask                  shape: (1024, 1024, 24)      min:    0.00000  max:    1.00000  bool

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  131.30000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  int64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
import skimage


class_names = ['stone']

# Load a random image from the images folder
IMAGE_DIR = "/cai_hdd/Sampyo_backup/crop_dataset_v6F/big/0"

file_names = next(os.walk(IMAGE_DIR))[2]
image = skimage.io.imread("/cai_hdd/Sampyo_backup/crop_dataset_v6F/big/99/\
G_99_3_up_c_1.1_0.0_nan_6.87515149416531_100.0_100.0_82.78160601128847_60.190796080196684_26.437896049032172_2.3806225977353823_0.8847259254129325_1_4.jpg")

# Run detection
results = model.detect([image], verbose=1)

# Visualize results
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                           ['BG', 'stone'], r['scores'])
# Out:
# Processing 1 images
# image                    shape: (2550, 1700, 3)       min:    0.00000  max:  238.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  123.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 2550.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
print(config.NAME)

# %%
import coco
# Load dataset
if config.NAME == 'shapes':
    dataset = shapes.ShapesDataset()
    dataset.load_shapes(500, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
elif config.NAME == "MaskRCNN_config":
    dataset = coco.CocoDataset()
    dataset.load_coco(dataset_dir, "train")

# Must call before using the dataset
dataset.prepare()

print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))

# %%
images_dir = dataset_dir + 'image_MRCNN'
for filename in listdir(images_dir):
    # extract image id
    image_name = filename.split("_")
    image_id = (image_name[4])
    annotations_dir = dataset_dir + 'annotation_MRCNN/'
    ann_path = annotations_dir + "_groundtruth_(1)_images_stone_1.png_" + str(image_id[:-4])
    print(ann_path)

# %%
class StoneDataset(Dataset):
    # load the dataset definitions
    def load_dataset(self, dataset_dir, is_train=True):
        
        # Add classes. We have only one class to add.
        self.add_class("dataset", 1, "stone")
        
        # define data locations for images and annotations
        images_dir = dataset_dir + 'image_MRCNN/'
        annotations_dir = dataset_dir + 'annotation_MRCNN/'
        
        # Iterate through all files in the folder to 
        #add class, images and annotaions
        for filename in listdir(images_dir):
            
            # extract image id
            image_name = filename.split("_")
            image_id = (image_name[4])
#             # skip bad images
#             if image_id in ['00090']:
#                 continue
#             # skip all images after 150 if we are building the train set
#             if is_train and int(image_id) >= 150:
#                 continue
#             # skip all images before 150 if we are building the test/val set
#             if not is_train and int(image_id) < 150:
#                 continue
            
            # setting image file
            img_path = images_dir + filename
            
            # setting annotations file
            ann_path = annotations_dir + "_groundtruth_(1)_images_stone_1.png_" + str(image_id[:-4]) + '.json'
            
            # adding images and annotations to dataset
            self.add_image('dataset', image_id=image_id, path=img_path, annotation=ann_path)
# extract bounding boxes from an annotation file
    def extract_boxes(self, filename):
        
        # load and parse the file
        tree = ElementTree.parse(filename)
        # get the root of the document
        root = tree.getroot()
        # extract each bounding box
        boxes = list()
        for box in root.findall('.//bndbox'):
            xmin = int(box.find('xmin').text)
            ymin = int(box.find('ymin').text)
            xmax = int(box.find('xmax').text)
            ymax = int(box.find('ymax').text)
            coors = [xmin, ymin, xmax, ymax]
            boxes.append(coors)
        
        # extract image dimensions
        width = int(root.find('.//size/width').text)
        height = int(root.find('.//size/height').text)
        return boxes, width, height
# load the masks for an image
    """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
     """
    def load_mask(self, image_id):
        # get details of image
        info = self.image_info[image_id]
        
        # define anntation  file location
        path = info['annotation']
        
        # load XML
        boxes, w, h = self.extract_boxes(path)
       
        # create one array for all masks, each on a different channel
        masks = zeros([h, w, len(boxes)], dtype='uint8')
        
        # create masks
        class_ids = list()
        for i in range(len(boxes)):
            box = boxes[i]
            row_s, row_e = box[1], box[3]
            col_s, col_e = box[0], box[2]
            masks[row_s:row_e, col_s:col_e, i] = 1
            class_ids.append(self.class_names.index('kangaroo'))
        return masks, asarray(class_ids, dtype='int32')
# load an image reference
     #"""Return the path of the image."""
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        print(info)
        return info['path']

# %%
# prepare train set
train_set = StoneDataset()
train_set.load_dataset(dataset_dir, is_train=True)
train_set.prepare()

print("Image Count: {}".format(len(train_set.image_ids)))
print("Class Count: {}".format(train_set.num_classes))
for i, info in enumerate(train_set.class_info):
    print("{:3}. {:50}".format(i, info['name']))

# %%
# Load and display random samples
image_ids = np.random.choice(train_set.image_ids, 1)
for image_id in image_ids:
    image = train_set.load_image(image_id)
    mask, class_ids = train_set.load_mask(image_id)
#     visualize.display_top_masks(image, mask, class_ids, train_set.class_names)
